# %%
import os
import numpy as np
from IPython.display import display
import torch
from data import adult
def statistics(log_path, protected_var):
    n_success = 0
    n_total = 0
    n_query = []
    n_sensitive_change = 0
    with open(os.path.join('log', f'{log_path}.log'),'r') as f:
        lines = f.readlines()
        for line in lines[1:]:
            t, s, n, p = line.split('\t')
            n_success += int(s)
            n_total += 1
            n_query.append(int(n))
            p = eval(p)
            if p != None:
                p = adult.get_original_feature(torch.tensor(p))
                if p[protected_var][0] != p[protected_var][1]:
                    n_sensitive_change += 1
    n_query = np.array(n_query)
    print('success:', f'{n_success}/{n_total}', '\naverage n_query:', n_query.mean(), '\nstd of n_query',  n_query.std(), '\nnum of pairs that changed protected var', n_sensitive_change)

# %%
statistics('Causal_race_White_test_black', protected_var='race_White')
# Out:
# success: 1000/1000
# average n_query: 1350.949
# std of n_query 9452.218114199388
# num of pairs that changed protected var 976

# %%
def show_pairs(log_path, show_range=None):
    with open(os.path.join('log', f'{log_path}.log'),'r') as f:
        lines = f.readlines()
        if show_range != None:
            lines = lines[show_range[0] : show_range[1]]
        else:
            lines = lines[1:]
        for line in lines:
            t, s, n, p = line.split('\t')
            if p != 'None':
                p = torch.tensor(eval(p))
                display(adult.get_original_feature(p))

# %%
show_pairs('Causal_race_White_test_black', [10, 20])
# Out:
#    age  capital-gain  capital-loss  education-num  hours-per-week  race_White  \
# 0   20          3874           273              6              50           0
# 1   20          3874           273              6              50           1
#
#    sex_Male  marital-status  occupation  relationship  workclass
# 0         0               5           5             3          2
# 1         0               5           5             3          2
#    age  capital-gain  capital-loss  education-num  hours-per-week  race_White  \
# 0   56          1284           988              8              48           0
# 1   56          1284           988              8              48           1
#
#    sex_Male  marital-status  occupation  relationship  workclass
# 0         0               2           4             3          5
# 1         0               2           4             3          5
#    age  capital-gain  capital-loss  education-num  hours-per-week  race_White  \
# ...

# %%
show_pairs('Causal_race_White_test_white', [10, 20])
# Out:
#    age  capital-gain  capital-loss  education-num  hours-per-week  race_White  \
# 0   20          3870           274              6              50           0
# 1   20          3870           274              6              50           1
#
#    sex_Male  marital-status  occupation  relationship  workclass
# 0         0               5           5             3          2
# 1         0               5           5             3          2
#    age  capital-gain  capital-loss  education-num  hours-per-week  race_White  \
# 0   56          1763           944              8              48           0
# 1   56          1763           944              8              48           1
#
#    sex_Male  marital-status  occupation  relationship  workclass
# 0         0               2           4             3          5
# 1         0               2           4             3          5
#    age  capital-gain  capital-loss  education-num  hours-per-week  race_White  \
# ...
